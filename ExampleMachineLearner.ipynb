# %% [markdown]
# Created on Fri Oct  5 11:06:19 2018
#
# Example machine learning exercise that would add to total score across all
# machine learning exercises as follows:
#
#     Data set - Low Accomplished
#     Pre-processing - Developing
#     Algorithm training and evaluation - Developing
#     Visualisation - Exemplary
#
# Author: Pepijn.VandeVen

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_moons
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing

# %% [markdown]
# Create some random data grouped into two groups

# %%
features, categories = make_moons(n_samples=1000, noise=0.05)
features = preprocessing.scale(features)

# %% [markdown]
# Train..

# %%
logreg = LogisticRegression(solver='lbfgs')
logreg.fit(features, categories)

print("Score after training: ",logreg.score(features,categories))
# Out:
# Score after training:  0.887

# %% [markdown]
# Visualise decision boundary by predicting categories over grid
# Based on: http://scikit-learn.org/stable/auto_examples/linear_model/plot_sgd_iris.html

# %%
x_min, x_max = features[:, 0].min() - .5, features[:, 0].max() + .5
y_min, y_max = features[:, 1].min() - .5, features[:, 1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = logreg.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot the training points on top
plt.scatter(features[:, 0], features[:, 1], c=categories)
plt.title('Final decision boundary visualised with normalised data set')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
